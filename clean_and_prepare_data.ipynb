# %%
import pandas as pd

# загрузка данных
file_path = './data/data_raw_english_columns.csv'
df = pd.read_csv(file_path, low_memory=False)

# вывод 5 первых строк
df.head(5)
# Out:
#      year                      program_group  \
# 0  2024.0                         Психология
# 1  2024.0    Лингвистика и иностранные языки
# 2  2024.0                      Юриспруденция
# 3  2024.0                Физическая культура
# 4  2024.0  Реклама и связи с общественностью
#
#                          university  avg_ege_paid  ege_change_prev_year  \
# 0  Адыгейский гос. ун-т., г. Майкоп          57.2                 -10.8
# 1  Адыгейский гос. ун-т., г. Майкоп          61.3                   5.7
# 2  Адыгейский гос. ун-т., г. Майкоп          55.7                  -7.4
# 3  Адыгейский гос. ун-т., г. Майкоп          45.9                  -2.4
# 4  Адыгейский гос. ун-т., г. Майкоп          52.0                   4.7
#
#    enrolled_paid cost_of_education_rub avg_ege_budget  enrolled_budget  \
# 0            3.0                 113.4           68.7             22.0
# 1           17.0                 113.4           76.6             25.0
# 2           30.0                 113.4           82.3             10.0
# 3            2.0                 158.3           63.3             50.0
# 4            2.0                 113.4           70.2             12.0
#
#   ege_excludes_individual  ...  inflation_rate_percent  mrot_rub  \
# 0                      Да  ...                     7.4      19.2
# 1                      Да  ...                     7.4      19.2
# 2                      Да  ...                     7.4      19.2
# 3                      Да  ...                     7.4      19.2
# 4                      Да  ...                     7.4      19.2
#
#    avg_salary_rub  real_salary_growth_percent  cpi_index  base_cpi  \
# 0            75.0                         8.5      251.3     100.6
# 1            75.0                         8.5      251.3     100.6
# 2            75.0                         8.5      251.3     100.6
# 3            75.0                         8.5      251.3     100.6
# 4            75.0                         8.5      251.3     100.6
#
#    base_inflation_percent  gdp_deflator  population_million  \
# 0                    7.15         129.4               146.2
# 1                    7.15         129.4               146.2
# 2                    7.15         129.4               146.2
# 3                    7.15         129.4               146.2
# 4                    7.15         129.4               146.2
#
#    unemployment_rate_percent
# 0                        2.9
# 1                        2.9
# 2                        2.9
# 3                        2.9
# 4                        2.9
#
# [5 rows x 23 columns]

# %%
# общая информация о данных
df_description = df.describe(include='all')
df_description
# Out:
#                 year program_group  \
# count   33221.000000         33221
# unique           NaN            68
# top              NaN     Экономика
# freq             NaN          2982
# mean     2020.797929           NaN
# std         2.053928           NaN
# min      2018.000000           NaN
# 25%      2019.000000           NaN
# 50%      2021.000000           NaN
# 75%      2023.000000           NaN
# max      2024.000000           NaN
#
#                                           university  avg_ege_paid  \
# count                                          33221  33221.000000
# unique                                           962           NaN
# top     Уральский федеральный ун-т. им. Б.Н. Ельцина           NaN
# freq                                             288           NaN
# mean                                             NaN     59.552957
# std                                              NaN      8.880795
# min                                              NaN      0.000000
# 25%                                              NaN     54.200000
# 50%                                              NaN     59.500000
# 75%                                              NaN     64.700000
# max                                              NaN     95.500000
#
#         ege_change_prev_year  enrolled_paid cost_of_education_rub  \
# count           27597.000000   33221.000000                 33221
# unique                   NaN            NaN                  2556
# top                      NaN            NaN            нет данных
# freq                     NaN            NaN                  1099
# mean                0.265804      38.741970                   NaN
# std                 5.358092      80.510412                   NaN
# min               -45.100000       1.000000                   NaN
# 25%                -2.400000       5.000000                   NaN
# 50%                 0.200000      14.000000                   NaN
# 75%                 2.900000      37.000000                   NaN
# max                51.400000    1760.000000                   NaN
#
#        avg_ege_budget  enrolled_budget ege_excludes_individual  ...  \
# count           26496     31805.000000                   33221  ...
# unique            556              NaN                     368  ...
# top                Да              NaN                      Да  ...
# freq             4318              NaN                   20079  ...
# mean              NaN        54.654061                     NaN  ...
# std               NaN        99.200654                     NaN  ...
# min               NaN         0.000000                     NaN  ...
# 25%               NaN         6.000000                     NaN  ...
# 50%               NaN        24.000000                     NaN  ...
# 75%               NaN        67.000000                     NaN  ...
# max               NaN      1706.000000                     NaN  ...
#
#         inflation_rate_percent      mrot_rub  avg_salary_rub  \
# count             33221.000000  33221.000000    33221.000000
# unique                     NaN           NaN             NaN
# top                        NaN           NaN             NaN
# freq                       NaN           NaN             NaN
# mean                  5.833272     13.324084       52.117248
# std                   3.145725      3.050213       11.836023
# min                   2.200000      9.490000       39.000000
# 25%                   2.430000     11.300000       42.300000
# 50%                   5.190000     12.800000       49.500000
# 75%                   8.370000     16.200000       63.300000
# max                  11.800000     19.200000       75.000000
#
#         real_salary_growth_percent     cpi_index      base_cpi  \
# count                 33221.000000  33221.000000  33221.000000
# unique                         NaN           NaN           NaN
# top                            NaN           NaN           NaN
# freq                           NaN           NaN           NaN
# mean                      4.467448    200.446118    100.449186
# std                       4.173611     28.253185      0.212123
# min                       0.100000    170.100000    100.200000
# 25%                       0.600000    178.600000    100.200000
# 50%                       1.900000    192.400000    100.500000
# 75%                       8.500000    233.900000    100.600000
# max                      11.000000    251.300000    100.800000
#
#         base_inflation_percent  gdp_deflator  population_million  \
# count             33221.000000         33221        33221.000000
# unique                     NaN             7                 NaN
# top                        NaN        106.92                 NaN
# freq                       NaN          5841                 NaN
# mean                  5.917807           NaN          146.618822
# std                   3.831234           NaN            0.302078
# min                   1.900000           NaN          146.200000
# 25%                   2.660000           NaN          146.200000
# 50%                   4.550000           NaN          146.700000
# 75%                   9.240000           NaN          146.900000
# max                  13.720000           NaN          147.000000
#
#         unemployment_rate_percent
# count                33221.000000
# unique                        NaN
# top                           NaN
# freq                          NaN
# mean                     4.536531
# std                      0.887520
# min                      2.900000
# 25%                      3.600000
# 50%                      4.700000
# 75%                      5.200000
# max                      5.800000
#
# [11 rows x 23 columns]

# %%
# общая информация о данных
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33222 entries, 0 to 33221
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   year                        33221 non-null  float64
#  1   program_group               33221 non-null  object
#  2   university                  33221 non-null  object
#  3   avg_ege_paid                33221 non-null  float64
#  4   ege_change_prev_year        27597 non-null  float64
#  5   enrolled_paid               33221 non-null  float64
#  6   cost_of_education_rub       33221 non-null  object
#  7   avg_ege_budget              26496 non-null  object
#  8   enrolled_budget             31805 non-null  float64
#  9   ege_excludes_individual     33221 non-null  object
#  10  gdp_per_capita_usd          33221 non-null  float64
#  11  gdp_usd_billion             33221 non-null  float64
#  12  gdp_rub_billion             33221 non-null  float64
#  13  inflation_rate_percent      33221 non-null  float64
#  14  mrot_rub                    33221 non-null  float64
#  15  avg_salary_rub              33221 non-null  float64
#  16  real_salary_growth_percent  33221 non-null  float64
#  17  cpi_index                   33221 non-null  float64
#  18  base_cpi                    33221 non-null  float64
#  19  base_inflation_percent      33221 non-null  float64
#  20  gdp_deflator                33221 non-null  object
#  21  population_million          33221 non-null  float64
#  22  unemployment_rate_percent   33221 non-null  float64
# dtypes: float64(17), object(6)
# memory usage: 5.8+ MB

# %%
# общая информация о данных
print("\nОбщая информация о данных:")
print(f"Количество строк: {len(df)}")
print(f"Количество столбцов: {len(df.columns)}")

# наличие дубликатов
print(f"\nКоличество дубликатов: {df.duplicated().sum()}")

# наличие пропущенных значений
print("\nКоличество пропущенных значений в каждом столбце:")
print(df.isna().sum())
# Out:
# Общая информация о данных:
# Количество строк: 33222
# Количество столбцов: 23
#
# Количество дубликатов: 0
#
# Количество пропущенных значений в каждом столбце:
# year                             1
# program_group                    1
# university                       1
# avg_ege_paid                     1
# ege_change_prev_year          5625
# enrolled_paid                    1
# cost_of_education_rub            1
# avg_ege_budget                6726
# enrolled_budget               1417
# ege_excludes_individual          1
# gdp_per_capita_usd               1
# gdp_usd_billion                  1
# gdp_rub_billion                  1
# inflation_rate_percent           1
# mrot_rub                         1
# avg_salary_rub                   1
# real_salary_growth_percent       1
# cpi_index                        1
# base_cpi                         1
# base_inflation_percent           1
# gdp_deflator                     1
# population_million               1
# unemployment_rate_percent        1
# dtype: int64

# %%
# получение списка столбцов с пропущенными значениями
df_missing = df.isnull().sum()

print(df_missing)
 # вывод списка столбцов с пропущенными значениями > 0 с пропущенными значениями
df_missing = df_missing[df_missing > 0]
print(df_missing)
# Out:
# year                             1
# program_group                    1
# university                       1
# avg_ege_paid                     1
# ege_change_prev_year          5625
# enrolled_paid                    1
# cost_of_education_rub            1
# avg_ege_budget                6726
# enrolled_budget               1417
# ege_excludes_individual          1
# gdp_per_capita_usd               1
# gdp_usd_billion                  1
# gdp_rub_billion                  1
# inflation_rate_percent           1
# mrot_rub                         1
# avg_salary_rub                   1
# real_salary_growth_percent       1
# cpi_index                        1
# base_cpi                         1
# base_inflation_percent           1
# gdp_deflator                     1
# population_million               1
# unemployment_rate_percent        1
# dtype: int64
# year                             1
# program_group                    1
# university                       1
# avg_ege_paid                     1
# ege_change_prev_year          5625
# enrolled_paid                    1
# cost_of_education_rub            1
# avg_ege_budget                6726
# enrolled_budget               1417
# ege_excludes_individual          1
# gdp_per_capita_usd               1
# gdp_usd_billion                  1
# gdp_rub_billion                  1
# inflation_rate_percent           1
# mrot_rub                         1
# avg_salary_rub                   1
# real_salary_growth_percent       1
# cpi_index                        1
# base_cpi                         1
# base_inflation_percent           1
# gdp_deflator                     1
# population_million               1
# unemployment_rate_percent        1
# dtype: int64

# %%
# Преобразование типов данных
cols_to_convert = ['cost_of_education_rub', 'avg_ege_budget', 'gdp_deflator']
df[cols_to_convert] = df[cols_to_convert].apply(pd.to_numeric, errors='coerce')

# проверка результата данных
converted_info = df[cols_to_convert].info()
new_missing = df[cols_to_convert].isnull().sum()
print(df[['cost_of_education_rub', 'avg_ege_budget', 'gdp_deflator']].describe())
converted_info, new_missing[new_missing > 0]  # Show only columns with missing values after conversion
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33222 entries, 0 to 33221
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   cost_of_education_rub  32122 non-null  float64
#  1   avg_ege_budget         20655 non-null  float64
#  2   gdp_deflator           27625 non-null  float64
# dtypes: float64(3)
# memory usage: 778.8 KB
#        cost_of_education_rub  avg_ege_budget  gdp_deflator
# count           32122.000000    20655.000000  27625.000000
# mean              161.190050       74.496156    122.013002
# std                79.066265        9.990435     12.844890
# min                30.000000       40.400000    106.920000
# 25%               111.600000       67.700000    113.600000
# 50%               135.000000       74.600000    117.750000
# 75%               188.700000       81.400000    129.400000
# max               862.000000      100.000000    146.760000
# (None,
#  cost_of_education_rub     1100
#  avg_ege_budget           12567
#  gdp_deflator              5597
#  dtype: int64)

# %%
# заполнение пропущенных значений медианой по каждому столбцу
for col in ['cost_of_education_rub', 'avg_ege_budget', 'gdp_deflator']:
    median_value = df[col].median()
    df[col] = df[col].fillna(median_value)
print(df[['cost_of_education_rub', 'avg_ege_budget', 'gdp_deflator']].describe())
# Out:
#        cost_of_education_rub  avg_ege_budget  gdp_deflator
# count           33222.000000    33222.000000  33222.000000
# mean              160.322882       74.535437    121.294802
# std                77.887341        7.877510     11.821159
# min                30.000000       40.400000    106.920000
# 25%               112.225000       72.100000    113.600000
# 50%               135.000000       74.600000    117.750000
# 75%               185.000000       77.100000    129.400000
# max               862.000000      100.000000    146.760000

# %%
# остались ли пропущенные значения в этих столбцах
remaining_nans = df[['cost_of_education_rub', 'avg_ege_budget', 'gdp_deflator']].isnull().sum()
print(remaining_nans)
# Out:
# cost_of_education_rub    0
# avg_ege_budget           0
# gdp_deflator             0
# dtype: int64

# %%
df_description = df.describe(include='all')
df_description
# Out:
#                 year program_group  \
# count   33221.000000         33221
# unique           NaN            68
# top              NaN     Экономика
# freq             NaN          2982
# mean     2020.797929           NaN
# std         2.053928           NaN
# min      2018.000000           NaN
# 25%      2019.000000           NaN
# 50%      2021.000000           NaN
# 75%      2023.000000           NaN
# max      2024.000000           NaN
#
#                                           university  avg_ege_paid  \
# count                                          33221  33221.000000
# unique                                           962           NaN
# top     Уральский федеральный ун-т. им. Б.Н. Ельцина           NaN
# freq                                             288           NaN
# mean                                             NaN     59.552957
# std                                              NaN      8.880795
# min                                              NaN      0.000000
# 25%                                              NaN     54.200000
# 50%                                              NaN     59.500000
# 75%                                              NaN     64.700000
# max                                              NaN     95.500000
#
#         ege_change_prev_year  enrolled_paid  cost_of_education_rub  \
# count           27597.000000   33221.000000           33222.000000
# unique                   NaN            NaN                    NaN
# top                      NaN            NaN                    NaN
# freq                     NaN            NaN                    NaN
# mean                0.265804      38.741970             160.322882
# std                 5.358092      80.510412              77.887341
# min               -45.100000       1.000000              30.000000
# 25%                -2.400000       5.000000             112.225000
# 50%                 0.200000      14.000000             135.000000
# 75%                 2.900000      37.000000             185.000000
# max                51.400000    1760.000000             862.000000
#
#         avg_ege_budget  enrolled_budget ege_excludes_individual  ...  \
# count     33222.000000     31805.000000                   33221  ...
# unique             NaN              NaN                     368  ...
# top                NaN              NaN                      Да  ...
# freq               NaN              NaN                   20079  ...
# mean         74.535437        54.654061                     NaN  ...
# std           7.877510        99.200654                     NaN  ...
# min          40.400000         0.000000                     NaN  ...
# 25%          72.100000         6.000000                     NaN  ...
# 50%          74.600000        24.000000                     NaN  ...
# 75%          77.100000        67.000000                     NaN  ...
# max         100.000000      1706.000000                     NaN  ...
#
#         inflation_rate_percent      mrot_rub  avg_salary_rub  \
# count             33221.000000  33221.000000    33221.000000
# unique                     NaN           NaN             NaN
# top                        NaN           NaN             NaN
# freq                       NaN           NaN             NaN
# mean                  5.833272     13.324084       52.117248
# std                   3.145725      3.050213       11.836023
# min                   2.200000      9.490000       39.000000
# 25%                   2.430000     11.300000       42.300000
# 50%                   5.190000     12.800000       49.500000
# 75%                   8.370000     16.200000       63.300000
# max                  11.800000     19.200000       75.000000
#
#         real_salary_growth_percent     cpi_index      base_cpi  \
# count                 33221.000000  33221.000000  33221.000000
# unique                         NaN           NaN           NaN
# top                            NaN           NaN           NaN
# freq                           NaN           NaN           NaN
# mean                      4.467448    200.446118    100.449186
# std                       4.173611     28.253185      0.212123
# min                       0.100000    170.100000    100.200000
# 25%                       0.600000    178.600000    100.200000
# 50%                       1.900000    192.400000    100.500000
# 75%                       8.500000    233.900000    100.600000
# max                      11.000000    251.300000    100.800000
#
#         base_inflation_percent  gdp_deflator  population_million  \
# count             33221.000000  33222.000000        33221.000000
# unique                     NaN           NaN                 NaN
# top                        NaN           NaN                 NaN
# freq                       NaN           NaN                 NaN
# mean                  5.917807    121.294802          146.618822
# std                   3.831234     11.821159            0.302078
# min                   1.900000    106.920000          146.200000
# 25%                   2.660000    113.600000          146.200000
# 50%                   4.550000    117.750000          146.700000
# 75%                   9.240000    129.400000          146.900000
# max                  13.720000    146.760000          147.000000
#
#         unemployment_rate_percent
# count                33221.000000
# unique                        NaN
# top                           NaN
# freq                          NaN
# mean                     4.536531
# std                      0.887520
# min                      2.900000
# 25%                      3.600000
# 50%                      4.700000
# 75%                      5.200000
# max                      5.800000
#
# [11 rows x 23 columns]

# %%
print(df['ege_excludes_individual'])

# преобразование значений "Да" и "Нет" в булевы значения True и False
df['ege_excludes_individual'] = df['ege_excludes_individual'].map({'Да': True, 'Нет': False})

# какие уникальные значения теперь содержит этот столбец
unique_values = df['ege_excludes_individual'].unique()
# Out:
# 0         Да
# 1         Да
# 2         Да
# 3         Да
# 4         Да
#         ...
# 33217     16
# 33218      0
# 33219      0
# 33220     15
# 33221    NaN
# Name: ege_excludes_individual, Length: 33222, dtype: object

# %%
# получение количества пропущенных значений
missing_values = df.isna().sum()

# вывод количества пропущенных значений
print("Number of missing values in each column:")
print(missing_values)

# показать только столбцы с пропущенными значениями
missing_values = missing_values[missing_values > 0]
if not missing_values.empty:
    print("\nColumns with missing values:")
    print(missing_values)
else:
    print("\nNo columns have missing values.")
# Out:
# Number of missing values in each column:
# year                             1
# program_group                    1
# university                       1
# avg_ege_paid                     1
# ege_change_prev_year          5625
# enrolled_paid                    1
# cost_of_education_rub            0
# avg_ege_budget                   0
# enrolled_budget               1417
# ege_excludes_individual       5842
# gdp_per_capita_usd               1
# gdp_usd_billion                  1
# gdp_rub_billion                  1
# inflation_rate_percent           1
# mrot_rub                         1
# avg_salary_rub                   1
# real_salary_growth_percent       1
# cpi_index                        1
# base_cpi                         1
# base_inflation_percent           1
# gdp_deflator                     0
# population_million               1
# unemployment_rate_percent        1
# dtype: int64
#
# Columns with missing values:
# year                             1
# program_group                    1
# university                       1
# avg_ege_paid                     1
# ege_change_prev_year          5625
# enrolled_paid                    1
# enrolled_budget               1417
# ege_excludes_individual       5842
# gdp_per_capita_usd               1
# gdp_usd_billion                  1
# gdp_rub_billion                  1
# inflation_rate_percent           1
# mrot_rub                         1
# avg_salary_rub                   1
# real_salary_growth_percent       1
# cpi_index                        1
# base_cpi                         1
# base_inflation_percent           1
# population_million               1
# unemployment_rate_percent        1
# dtype: int64

# %%
# включение опции "future.no_silent_downcasting" чтобы убрать предупреждение
pd.set_option('future.no_silent_downcasting', True)
# обработка оставшихся пропусков
numeric_fill_median = ['year', 'avg_ege_paid', 'enrolled_paid', 'enrolled_budget', 'gdp_per_capita_usd']
# заполнение пропущенных значений медианой
for col in numeric_fill_median:
    df[col] = df[col].fillna(df[col].median())

# %%
# вставляем самое частое значение в пропуски
categorical_fill_mode = ['program_group', 'university']
for col in categorical_fill_mode:
    df[col] = df[col].fillna(df[col].mode()[0])

# вставляем False в пропуски
df['ege_excludes_individual'] = df['ege_excludes_individual'].fillna(False)
df['ege_excludes_individual'] = df['ege_excludes_individual'].infer_objects(copy=False)

# вставляем 0 в пропуски
df['ege_change_prev_year'] = df['ege_change_prev_year'].fillna(0)

# проверка оставшихся пропущенных значений
missing_values = df.isnull().sum()
print(missing_values)
print(df['ege_change_prev_year'])
print(df.head(10))
# Out:
# year                          0
# program_group                 0
# university                    0
# avg_ege_paid                  0
# ege_change_prev_year          0
# enrolled_paid                 0
# cost_of_education_rub         0
# avg_ege_budget                0
# enrolled_budget               0
# ege_excludes_individual       0
# gdp_per_capita_usd            0
# gdp_usd_billion               1
# gdp_rub_billion               1
# inflation_rate_percent        1
# mrot_rub                      1
# avg_salary_rub                1
# real_salary_growth_percent    1
# cpi_index                     1
# base_cpi                      1
# base_inflation_percent        1
# gdp_deflator                  0
# population_million            1
# unemployment_rate_percent     1
# dtype: int64
# 0       -10.8
# 1         5.7
# 2        -7.4
# 3        -2.4
# 4         4.7
#          ...
# 33217     1.8
# 33218     0.0
# 33219     0.0
# 33220     0.0
# 33221     0.0
# Name: ege_change_prev_year, Length: 33222, dtype: float64
#      year                      program_group  \
# 0  2024.0                         Психология
# 1  2024.0    Лингвистика и иностранные языки
# 2  2024.0                      Юриспруденция
# 3  2024.0                Физическая культура
# 4  2024.0  Реклама и связи с общественностью
# 5  2024.0                          Экономика
# 6  2024.0        Информационная безопасность
# 7  2024.0         Педагогическое образование
# 8  2024.0                         Менеджмент
# 9  2024.0        Сельское и рыбное хозяйство
#
#                                           university  avg_ege_paid  \
# 0                   Адыгейский гос. ун-т., г. Майкоп          57.2
# 1                   Адыгейский гос. ун-т., г. Майкоп          61.3
# 2                   Адыгейский гос. ун-т., г. Майкоп          55.7
# 3                   Адыгейский гос. ун-т., г. Майкоп          45.9
# 4                   Адыгейский гос. ун-т., г. Майкоп          52.0
# 5                   Адыгейский гос. ун-т., г. Майкоп          58.6
# 6                   Адыгейский гос. ун-т., г. Майкоп          57.9
# 7                   Адыгейский гос. ун-т., г. Майкоп          56.3
# 8                   Адыгейский гос. ун-т., г. Майкоп          61.1
# 9  Азово-Черноморский инженерный ин-т. - филиал Д...          40.3
#
#    ege_change_prev_year  enrolled_paid  cost_of_education_rub  avg_ege_budget  \
# 0                 -10.8            3.0                  113.4            68.7
# 1                   5.7           17.0                  113.4            76.6
# 2                  -7.4           30.0                  113.4            82.3
# 3                  -2.4            2.0                  158.3            63.3
# 4                   4.7            2.0                  113.4            70.2
# 5                  -6.1            6.0                  113.4            74.6
# 6                   0.0            2.0                  129.9            62.2
# 7                   4.1           14.0                  113.4            65.8
# 8                   1.2           15.0                  113.4            74.6
# 9                   1.6            3.0                  138.8            46.7
#
#    enrolled_budget  ege_excludes_individual  ...  inflation_rate_percent  \
# 0             22.0                     True  ...                     7.4
# 1             25.0                     True  ...                     7.4
# 2             10.0                     True  ...                     7.4
# 3             50.0                     True  ...                     7.4
# 4             12.0                     True  ...                     7.4
# 5              0.0                     True  ...                     7.4
# 6             29.0                     True  ...                     7.4
# 7            146.0                     True  ...                     7.4
# 8              0.0                     True  ...                     7.4
# 9             69.0                    False  ...                     7.4
#
#    mrot_rub  avg_salary_rub  real_salary_growth_percent  cpi_index  base_cpi  \
# 0      19.2            75.0                         8.5      251.3     100.6
# 1      19.2            75.0                         8.5      251.3     100.6
# 2      19.2            75.0                         8.5      251.3     100.6
# 3      19.2            75.0                         8.5      251.3     100.6
# 4      19.2            75.0                         8.5      251.3     100.6
# 5      19.2            75.0                         8.5      251.3     100.6
# 6      19.2            75.0                         8.5      251.3     100.6
# 7      19.2            75.0                         8.5      251.3     100.6
# 8      19.2            75.0                         8.5      251.3     100.6
# 9      19.2            75.0                         8.5      251.3     100.6
#
#    base_inflation_percent  gdp_deflator  population_million  \
# 0                    7.15         129.4               146.2
# 1                    7.15         129.4               146.2
# 2                    7.15         129.4               146.2
# 3                    7.15         129.4               146.2
# 4                    7.15         129.4               146.2
# 5                    7.15         129.4               146.2
# 6                    7.15         129.4               146.2
# 7                    7.15         129.4               146.2
# 8                    7.15         129.4               146.2
# 9                    7.15         129.4               146.2
#
#    unemployment_rate_percent
# 0                        2.9
# 1                        2.9
# 2                        2.9
# 3                        2.9
# 4                        2.9
# 5                        2.9
# 6                        2.9
# 7                        2.9
# 8                        2.9
# 9                        2.9
#
# [10 rows x 23 columns]

# %%
print(df['enrolled_budget'])
df.fillna({
    'ege_change_prev_year': 0,
    'avg_ege_budget': df['avg_ege_budget'].median(),
    'cost_of_education_rub': df['cost_of_education_rub'].median(),
    'gdp_deflator': df['gdp_deflator'].median()
}, inplace=True)
# Out:
# 0        22.0
# 1        25.0
# 2        10.0
# 3        50.0
# 4        12.0
#          ...
# 33217    79.8
# 33218    24.0
# 33219    24.0
# 33220    79.6
# 33221    24.0
# Name: enrolled_budget, Length: 33222, dtype: float64

# %%
# список нужных столбцов
cols_to_convert = ['year', 'enrolled_paid', 'enrolled_budget']

# в числовой тип с обработкой ошибок
df[cols_to_convert] = df[cols_to_convert].apply(pd.to_numeric, errors='coerce')

# удаление строк с пропущенными значениями в этих столбцах
df = df.dropna(subset=cols_to_convert)

# Преобразуем к целому типу
df[cols_to_convert] = df[cols_to_convert].astype(int)


df.to_csv('./data/data_english_cleaned_1.csv', index=False)

# %% [markdown]
# # Exploratory Data Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# размер графиков по умолчанию
plt.rcParams['figure.figsize'] = (12, 6)

# общая численность студентов (платные + бюджетные)
df['total_enrolled'] = df['enrolled_paid'] + df['enrolled_budget']
students_by_year = df.groupby('year')['total_enrolled'].sum()

# общее количество студентов по всем университетам по годам'
plt.figure(figsize=(10, 6))
students_by_year.plot(kind='bar', color='skyblue')
plt.title('Общее количество студентов по всем университетам по годам')
plt.xlabel('Год')
plt.ylabel('Количество студентов')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# 2. средняя стоимость обучения по университетам.
# Группируем по университетам и считаем среднюю стоимость обучения
avg_cost_by_university = df.groupby('university')['cost_of_education_rub'].mean().sort_values(ascending=False)

# Оставим топ-20 университетов по стоимости
top_n = 20
top_avg_cost = avg_cost_by_university.head(top_n)

# горизонтальная диаграмма
plt.figure(figsize=(12, 8))
top_avg_cost.plot(kind='barh', color='coral')
plt.title(f'Средняя стоимость обучения (ТОП-{top_n} университетов)')
plt.xlabel('Стоимость обучения (руб.)')
plt.ylabel('Университет')
plt.gca().invert_yaxis()  # чтобы самый дорогой был сверху
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# 3. динамика поступлений по годам
df_year_grouped = df.groupby('year')[['enrolled_budget', 'enrolled_paid']].sum()
df_year_grouped.plot(marker='o')
plt.title('Количество поступивших студентов по годам')
plt.ylabel('Количество студентов')
plt.xlabel('Год')
plt.grid(True)
plt.show()

# %%
# 4. ТОП-10 университетов по среднему количеству студентов
top_universities = df.groupby('university')[['enrolled_budget', 'enrolled_paid']].mean().sum(axis=1).sort_values(ascending=False).head(10)
top_universities.plot(kind='bar')
plt.title('ТОП-10 университетов по среднему количеству студентов')
plt.ylabel('Среднее количество студентов')
plt.xlabel('Университет')
plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.show()

# %%
# 5. Распределение стоимости обучения
sns.histplot(df['cost_of_education_rub'], bins=30, kde=True)
plt.title('Распределение стоимости обучения (руб)')
plt.xlabel('Стоимость обучения')
plt.ylabel('Частота')
plt.grid(True)
plt.show()

# %%
# 6. популярность направлений подготовки (program_group)
program_counts = df['program_group'].value_counts().head(15)
program_counts.plot(kind='bar')
plt.title('ТОП-15 направлений по количеству записей')
plt.ylabel('Количество')
plt.xlabel('Группа программ')
plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.show()

# %%
# 7. Корреляционная матрица
numeric_columns = ['cost_of_education_rub', 'avg_ege_budget', 'avg_ege_paid',
                   'enrolled_paid', 'enrolled_budget', 'gdp_deflator', 'gdp_per_capita_usd', 'year']

correlation_matrix = df[numeric_columns].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Корреляционная матрица числовых признаков')
plt.show()

# %%
# 8. Стоимость обучения vs Баллы ЕГЭ (бюджет)
sns.scatterplot(data=df, x='cost_of_education_rub', y='avg_ege_budget', alpha=0.4)
plt.title('Стоимость обучения vs Средний балл ЕГЭ (бюджет)')
plt.xlabel('Стоимость обучения (руб)')
plt.ylabel('Средний балл ЕГЭ')
plt.grid(True)
plt.show()

# %%
# 9. Баллы ЕГЭ vs Количество поступивших (бюджет)
sns.scatterplot(data=df, x='avg_ege_budget', y='enrolled_budget', alpha=0.5)
plt.title('Средний балл ЕГЭ vs Количество поступивших (бюджет)')
plt.xlabel('Средний балл ЕГЭ')
plt.ylabel('Количество поступивших')
plt.grid(True)
plt.show()

# %%
# группировка по году
yearly = df.groupby("year")[['avg_ege_budget', 'cost_of_education_rub', 'enrolled_budget']].mean()

# создаём лаги (запаздывания)
yearly["enrolled_budget_t+1"] = yearly["enrolled_budget"].shift(-1)
yearly["enrolled_budget_t+2"] = yearly["enrolled_budget"].shift(-2)

# графики зависимости
sns.pairplot(yearly, x_vars=["avg_ege_budget", "cost_of_education_rub"],
             y_vars=["enrolled_budget_t+1", "enrolled_budget_t+2"],
             height=4, aspect=1.2, kind='reg')
plt.suptitle("Lag-анализ: Влияние ЕГЭ и стоимости на поступление через 1–2 года", y=1.02)
plt.show()

# %%
import missingno as msno

# Визуализация пропущенных значений
msno.matrix(df)
plt.title("Матрица пропущенных значений")
plt.show()

msno.heatmap(df)
plt.title("Корреляция пропусков между столбцами")
plt.show()

# %%
# создание целевой переменной спроса
df['total_enrolled'] = df['enrolled_paid'] + df['enrolled_budget']
df['demand'] = df['enrolled_paid'] / df['total_enrolled']
df['demand'] = df['demand'].fillna(0)

# %%
# Кодирование категорий
df = pd.get_dummies(df, columns=['program_group'], drop_first=True)
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['university'] = le.fit_transform(df['university'])

# %%
# нормализация числовых признаков (исключая целые числа)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
numeric_columns = df.select_dtypes(include=['float64']).columns
df[numeric_columns] = scaler.fit_transform(df[numeric_columns])

# %%
# проверка пропусков
print("\nКол-во пропусков в каждом столбце:")
missing_values = df.isna().sum()
print(missing_values)
missing_values = missing_values[missing_values > 0]
if not missing_values.empty:
    print("\nСтолбцы с пропущенными значениями:")
    print(missing_values)
else:
    print("\nНет пропущенных значений.")
# Out:
# Кол-во пропусков в каждом столбце:
# year                                                        0
# university                                                  0
# avg_ege_paid                                                0
# ege_change_prev_year                                        0
# enrolled_paid                                               0
#                                                            ..
# program_group_Экономика                                     0
# program_group_Электронная техника, радиотехника и связь     0
# program_group_Энергетика и энергетическое машиностроение    0
# program_group_Юриспруденция                                 0
# program_group_Ядерные физика и технологии                   0
# Length: 91, dtype: int64
#
# Столбцы с пропущенными значениями:
# gdp_usd_billion               1
# gdp_rub_billion               1
# inflation_rate_percent        1
# mrot_rub                      1
# avg_salary_rub                1
# real_salary_growth_percent    1
# cpi_index                     1
# base_cpi                      1
# base_inflation_percent        1
# population_million            1
# unemployment_rate_percent     1
# dtype: int64

# %%
# Проверка типов данных
print("\nColumn data types:")
print(df.dtypes)

# Сохранение DataFrame
df.to_csv('./data/cleaned_data.csv', index=False)
print("\nИнформация о DataFrame:")
df.info()
print("\nПервые 5 строк:")
print(df.head())
# Out:
# Column data types:
# year                                                          int64
# university                                                    int64
# avg_ege_paid                                                float64
# ege_change_prev_year                                        float64
# enrolled_paid                                                 int64
#                                                              ...
# program_group_Экономика                                        bool
# program_group_Электронная техника, радиотехника и связь        bool
# program_group_Энергетика и энергетическое машиностроение       bool
# program_group_Юриспруденция                                    bool
# program_group_Ядерные физика и технологии                      bool
# Length: 91, dtype: object
#
# Информация о DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33222 entries, 0 to 33221
# Data columns (total 91 columns):
#  #   Column                                                                                Non-Null Count  Dtype
# ---  ------                                                                                --------------  -----
#  0   year                                                                                  33222 non-null  int64
#  1   university                                                                            33222 non-null  int64
#  2   avg_ege_paid                                                                          33222 non-null  float64
#  3   ege_change_prev_year                                                                  33222 non-null  float64
#  4   enrolled_paid                                                                         33222 non-null  int64
#  5   cost_of_education_rub                                                                 33222 non-null  float64
#  6   avg_ege_budget                                                                        33222 non-null  float64
#  7   enrolled_budget                                                                       33222 non-null  int64
#  8   ege_excludes_individual                                                               33222 non-null  bool
#  9   gdp_per_capita_usd                                                                    33222 non-null  float64
#  10  gdp_usd_billion                                                                       33221 non-null  float64
#  11  gdp_rub_billion                                                                       33221 non-null  float64
#  12  inflation_rate_percent                                                                33221 non-null  float64
#  13  mrot_rub                                                                              33221 non-null  float64
#  14  avg_salary_rub                                                                        33221 non-null  float64
#  15  real_salary_growth_percent                                                            33221 non-null  float64
#  16  cpi_index                                                                             33221 non-null  float64
#  17  base_cpi                                                                              33221 non-null  float64
#  18  base_inflation_percent                                                                33221 non-null  float64
#  19  gdp_deflator                                                                          33222 non-null  float64
#  20  population_million                                                                    33221 non-null  float64
#  21  unemployment_rate_percent                                                             33221 non-null  float64
#  22  total_enrolled                                                                        33222 non-null  int64
#  23  demand                                                                                33222 non-null  float64
#  24  program_group_Авиационные системы (эксплуатация)                                      33222 non-null  bool
#  25  program_group_Автоматика и управление                                                 33222 non-null  bool
#  26  program_group_Актерское исполнительство                                               33222 non-null  bool
#  27  program_group_Архитектура и градостроительство                                        33222 non-null  bool
#  28  program_group_Библиотеки и архивы                                                     33222 non-null  bool
#  29  program_group_Бизнес-информатика                                                      33222 non-null  bool
#  30  program_group_Биология                                                                33222 non-null  bool
#  31  program_group_Вооружение                                                              33222 non-null  bool
#  32  program_group_Востоковедение и африканистика                                          33222 non-null  bool
#  33  program_group_География                                                               33222 non-null  bool
#  34  program_group_Геодезия и землеустройство                                              33222 non-null  bool
#  35  program_group_Геология                                                                33222 non-null  bool
#  36  program_group_Государственное и муниципальное управление                              33222 non-null  bool
#  37  program_group_Дизайн                                                                  33222 non-null  bool
#  38  program_group_Журналистика и литературное творчество                                  33222 non-null  bool
#  39  program_group_Здравоохранение                                                         33222 non-null  bool
#  40  program_group_Издательское дело                                                       33222 non-null  bool
#  41  program_group_Информатика и вычислительная техника                                    33222 non-null  bool
#  42  program_group_Информационная безопасность                                             33222 non-null  bool
#  43  program_group_История                                                                 33222 non-null  bool
#  44  program_group_Культурология                                                           33222 non-null  bool
#  45  program_group_Лесное дело                                                             33222 non-null  bool
#  46  program_group_Лингвистика и иностранные языки                                         33222 non-null  bool
#  47  program_group_Математика                                                              33222 non-null  bool
#  48  program_group_Материалы                                                               33222 non-null  bool
#  49  program_group_Машиностроение                                                          33222 non-null  bool
#  50  program_group_Международные отношения                                                 33222 non-null  bool
#  51  program_group_Менеджмент                                                              33222 non-null  bool
#  52  program_group_Металлургия                                                             33222 non-null  bool
#  53  program_group_Морская техника                                                         33222 non-null  bool
#  54  program_group_Нефтегазовое дело                                                       33222 non-null  bool
#  55  program_group_Охрана памятников                                                       33222 non-null  bool
#  56  program_group_Педагогическое образование                                              33222 non-null  bool
#  57  program_group_Пищевые технологии                                                      33222 non-null  bool
#  58  program_group_Полиграфия и упаковка                                                   33222 non-null  bool
#  59  program_group_Политология                                                             33222 non-null  bool
#  60  program_group_Почвоведение                                                            33222 non-null  bool
#  61  program_group_Приборостроение и оптотехника                                           33222 non-null  bool
#  62  program_group_Профессиональное обучение                                               33222 non-null  bool
#  63  program_group_Психология                                                              33222 non-null  bool
#  64  program_group_Психолого-педагогическое и специальное (дефектологическое) образование  33222 non-null  bool
#  65  program_group_Реклама и связи с общественностью                                       33222 non-null  bool
#  66  program_group_Религиоведение и теология                                               33222 non-null  bool
#  67  program_group_Сельское и рыбное хозяйство                                             33222 non-null  bool
#  68  program_group_Сестринское дело2                                                       33222 non-null  bool
#  69  program_group_Социальная работа                                                       33222 non-null  bool
#  70  program_group_Социология                                                              33222 non-null  bool
#  71  program_group_Строительство                                                           33222 non-null  bool
#  72  program_group_Сфера обслуживания                                                      33222 non-null  bool
#  73  program_group_Теория искусств                                                         33222 non-null  bool
#  74  program_group_Технологии легкой промышленности                                        33222 non-null  bool
#  75  program_group_Технологические машины и оборудование                                   33222 non-null  bool
#  76  program_group_Транспортные средства                                                   33222 non-null  bool
#  77  program_group_Управление водным транспортом                                           33222 non-null  bool
#  78  program_group_Управление качеством                                                    33222 non-null  bool
#  79  program_group_Физика                                                                  33222 non-null  bool
#  80  program_group_Физическая культура                                                     33222 non-null  bool
#  81  program_group_Филология                                                               33222 non-null  bool
#  82  program_group_Философия                                                               33222 non-null  bool
#  83  program_group_Химическая и биотехнологии                                              33222 non-null  bool
#  84  program_group_Химия                                                                   33222 non-null  bool
#  85  program_group_Экология                                                                33222 non-null  bool
#  86  program_group_Экономика                                                               33222 non-null  bool
#  87  program_group_Электронная техника, радиотехника и связь                               33222 non-null  bool
#  88  program_group_Энергетика и энергетическое машиностроение                              33222 non-null  bool
#  89  program_group_Юриспруденция                                                           33222 non-null  bool
#  90  program_group_Ядерные физика и технологии                                             33222 non-null  bool
# dtypes: bool(68), float64(18), int64(5)
# memory usage: 8.0 MB
#
# Первые 5 строк:
#    year  university  avg_ege_paid  ege_change_prev_year  enrolled_paid  \
# 0  2024           0     -0.264957             -2.256328              3
# 1  2024           0      0.196728              1.121777             17
# 2  2024           0     -0.433866             -1.560234             30
# 3  2024           0     -1.537404             -0.536566              2
# 4  2024           0     -0.850508              0.917043              2
#
#    cost_of_education_rub  avg_ege_budget  enrolled_budget  \
# 0              -0.602455       -0.740783               22
# 1              -0.602455        0.262087               25
# 2              -0.602455        0.985677               10
# 3              -0.025972       -1.426289               50
# 4              -0.602455       -0.550365               12
#
#    ege_excludes_individual  gdp_per_capita_usd  ...  program_group_Филология  \
# 0                     True            1.683339  ...                    False
# 1                     True            1.683339  ...                    False
# 2                     True            1.683339  ...                    False
# 3                     True            1.683339  ...                    False
# 4                     True            1.683339  ...                    False
#
#    program_group_Философия  program_group_Химическая и биотехнологии  \
# 0                    False                                     False
# 1                    False                                     False
# 2                    False                                     False
# 3                    False                                     False
# 4                    False                                     False
#
#    program_group_Химия  program_group_Экология  program_group_Экономика  \
# 0                False                   False                    False
# 1                False                   False                    False
# 2                False                   False                    False
# 3                False                   False                    False
# 4                False                   False                    False
#
#    program_group_Электронная техника, радиотехника и связь  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    program_group_Энергетика и энергетическое машиностроение  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    program_group_Юриспруденция  program_group_Ядерные физика и технологии
# 0                        False                                      False
# 1                        False                                      False
# 2                         True                                      False
# 3                        False                                      False
# 4                        False                                      False
#
# [5 rows x 91 columns]
