# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import csv

# %%
file = open('data.csv','w',encoding="utf-8") # Открываем файл на запись. Можно было использовать контекстный менеджер, но так думаю проще.
writer = csv.writer(file) # Передаем в функцию writer дескриптор открытого файла.
head_data=['year','program_group','university','avg_ege_paid','ege_change_prev_year','enrolled_paid','cost_of_education_rub','avg_ege_budget','enrolled_budget','ege_excludes_individual','gdp_per_capita_usd', 'gdp_usd_billion', 'gdp_rub_billion', 'inflation_rate_percent', 'mrot_rub', 'avg_salary_rub', 'real_salary_growth_percent', 'cpi_index', 'base_cpi', 'base_inflation_percent', 'gdp_deflator', 'population_million', 'unemployment_rate_percent']
writer.writerow(head_data)
head_data
# Out:
# ['year',
#  'program_group',
#  'university',
#  'avg_ege_paid',
#  'ege_change_prev_year',
#  'enrolled_paid',
#  'cost_of_education_rub',
#  'avg_ege_budget',
#  'enrolled_budget',
#  'ege_excludes_individual',
#  'gdp_per_capita_usd',
#  'gdp_usd_billion',
#  'gdp_rub_billion',
#  'inflation_rate_percent',
#  'mrot_rub',
#  'avg_salary_rub',
#  'real_salary_growth_percent',
#  'cpi_index',
#  'base_cpi',
#  'base_inflation_percent',
#  'gdp_deflator',
#  'population_million',
#  'unemployment_rate_percent']

# %%
links = ['https://ege.hse.ru/rating/2024/98633979/all/',
'https://ege.hse.ru/rating/2023/95405491/all/',
'https://ege.hse.ru/rating/2022/91645099/all/',
'https://ege.hse.ru/rating/2021/87901186/all/',
'https://ege.hse.ru/rating/2020/84025368/all/',
'https://ege.hse.ru/rating/2019/81058609/all/?rlist=&ptype=0&glist=0&vuz-abiturients-paid-order=ge&vuz-abiturients-paid-val=&price-order=ge&price-val=',
'https://ege.hse.ru/rating/2018/77479782/all/']
economics = [['2024', '10.4', '2.02', '32.3', '7.4', '19.2', '75', '8.5', '251.3', '100.6', '7.15', '129.4', '146.2', '2.9'],
['2023', '10', '2.27', '30.6', '11.8', '16.2', '63.3', '0.6', '233.9', '100.3', '13.72', '113.6', '146.4', '3.6'],
['2022', '10.2', '1.84', '30.9', '8.37', '13.9', '55.7', '1.9', '209.2', '100.8', '9.24', '146.76', '147', '4.4'],
['2021', '9.63', '1.49', '29.9', '5.19', '12.8', '49.5', '0.1', '192.4', '100.5', '4.55', '123.55', '146.2', '5.8'],
['2020', '9.88', '1.69', '29.6', '2.43', '12.1', '46.7', '6.5', '182.9', '100.2', '2.66', '117.75', '146.7', '4.7'],
['2019', '9.67', '1.66', '29.2', '4.97', '11.3', '42.3', '1.1', '178.6', '100.6', '4.13', '118.11', '146.8', '4.9'],
['2018', '9.42', '1.57', '28.8', '2.2', '9.49', '39', '11', '170.1', '100.2', '1.9', '106.92', '146.9', '5.2']]
year = 2025
i = 1
for link in links:
  i =+1
  year-= i
  print(year)
  for j in economics:
	  if int(j[0])==year:
		  economic_list = j[1:14]
  print(economic_list)
  page = requests.get(link)
  soup = BeautifulSoup(page.text, 'lxml')
  table1 = soup.find('table', id='transparence_t')
  rows = table1.find('tbody').find_all('tr')
  for row in rows: # Проходимся по всем строкам. При каждой итерации, в row у нас будет следующая строка таблицы, вместе с html тегами.
	  columns = row.find_all('td') # Ищем в текущей строке таблици все теги 'td'. В html td - это тег ячейки.
	  data_list = [year,columns[0].text.strip(),columns[1].text.strip(),columns[2].text.strip(),columns[3].text.strip(),columns[4].text.strip(),columns[5].text.strip(),columns[6].text.strip(),columns[7].text.strip(),columns[8].text.strip(),economic_list[0],economic_list[1],economic_list[2],economic_list[3],economic_list[4],economic_list[5],economic_list[6],economic_list[7],economic_list[8],economic_list[9],economic_list[10],economic_list[11],economic_list[12]]
	  # Так как в каждой строке 9 ячеек, а элементы списка в большинстве ЯП нумеруюются с нуля, то мы можем обратится к конкретной ячейке
	  # текущей строки по индексу. Первая ячейка будет columns[0], а последняя, тоесть девятая - columns[8]. Создаем список 'data_list',
	  # и заносим в него все ячейки текущей строки. Но, так как в columns кроме текстовых данных также присутствуют html теги, мы обращаемся
	  # к свойству .text, что-бы получить сам текст, без тегов.
	  writer.writerow(data_list)
data_list
# Out:
# 2024
# ['10.4', '2.02', '32.3', '7.4', '19.2', '75', '8.5', '251.3', '100.6', '7.15', '129.4', '146.2', '2.9']
# 2023
# ['10', '2.27', '30.6', '11.8', '16.2', '63.3', '0.6', '233.9', '100.3', '13.72', '113.6', '146.4', '3.6']
# 2022
# ['10.2', '1.84', '30.9', '8.37', '13.9', '55.7', '1.9', '209.2', '100.8', '9.24', '146.76', '147', '4.4']
# 2021
# ['9.63', '1.49', '29.9', '5.19', '12.8', '49.5', '0.1', '192.4', '100.5', '4.55', '123.55', '146.2', '5.8']
# 2020
# ['9.88', '1.69', '29.6', '2.43', '12.1', '46.7', '6.5', '182.9', '100.2', '2.66', '117.75', '146.7', '4.7']
# 2019
# ['9.67', '1.66', '29.2', '4.97', '11.3', '42.3', '1.1', '178.6', '100.6', '4.13', '118.11', '146.8', '4.9']
# 2018
# ['9.42', '1.57', '28.8', '2.2', '9.49', '39', '11', '170.1', '100.2', '1.9', '106.92', '146.9', '5.2']
# [2018,
#  'Экономика',
#  'Ярославский филиал Финансового ун-т.а при Правительстве РФ',
#  '63.7',
#  '',
#  '17',
#  '101.8',
#  'Нет',
#  '79.6',
#  '15',
#  '9.42',
#  '1.57',
#  '28.8',
#  '2.2',
#  '9.49',
#  '39',
#  '11',
#  '170.1',
#  '100.2',
#  '1.9',
#  '106.92',
#  '146.9',
#  '5.2']

# %%
file.close() # Так как мы не используем контекстный менеджер with, обязательно закрываем открытый файл.

# %%
import pandas as pd

# загрузка данных
file_path = '/content/data.csv'
df = pd.read_csv(file_path, low_memory=False)


df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33221 entries, 0 to 33220
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   year                        33221 non-null  int64
#  1   program_group               33221 non-null  object
#  2   university                  33221 non-null  object
#  3   avg_ege_paid                33221 non-null  float64
#  4   ege_change_prev_year        27597 non-null  float64
#  5   enrolled_paid               33221 non-null  int64
#  6   cost_of_education_rub       33221 non-null  object
#  7   avg_ege_budget              26496 non-null  object
#  8   enrolled_budget             31805 non-null  float64
#  9   ege_excludes_individual     33221 non-null  object
#  10  gdp_per_capita_usd          33221 non-null  float64
#  11  gdp_usd_billion             33221 non-null  float64
#  12  gdp_rub_billion             33221 non-null  float64
#  13  inflation_rate_percent      33221 non-null  float64
#  14  mrot_rub                    33221 non-null  float64
#  15  avg_salary_rub              33221 non-null  float64
#  16  real_salary_growth_percent  33221 non-null  float64
#  17  cpi_index                   33221 non-null  float64
#  18  base_cpi                    33221 non-null  float64
#  19  base_inflation_percent      33221 non-null  float64
#  20  gdp_deflator                33221 non-null  float64
#  21  population_million          33221 non-null  float64
#  22  unemployment_rate_percent   33221 non-null  float64
# dtypes: float64(16), int64(2), object(5)
# memory usage: 5.8+ MB

# %%
df.head(50)
# Out:
#     year                                      program_group  \
# 0   2024                                          Экономика
# 1   2024                                      Юриспруденция
# 2   2024                  Реклама и связи с общественностью
# 3   2024                                         Психология
# 4   2024                                Физическая культура
# 5   2024                                         Менеджмент
# 6   2024                        Информационная безопасность
# 7   2024                         Педагогическое образование
# 8   2024                    Лингвистика и иностранные языки
# 9   2024                        Сельское и рыбное хозяйство
# 10  2024                                          Экономика
# 11  2024                            Международные отношения
# 12  2024                                         Менеджмент
# 13  2024                                         Психология
# 14  2024               Информатика и вычислительная техника
# 15  2024                  Реклама и связи с общественностью
# 16  2024                                 Сфера обслуживания
# 17  2024                         Педагогическое образование
# 18  2024                                             Дизайн
# 19  2024         Государственное и муниципальное управление
# 20  2024                                      Юриспруденция
# 21  2024                  Реклама и связи с общественностью
# 22  2024                    Лингвистика и иностранные языки
# 23  2024                                        Политология
# 24  2024         Государственное и муниципальное управление
# 25  2024                                      Юриспруденция
# 26  2024                                          Экономика
# 27  2024                                      Юриспруденция
# 28  2024                                         Менеджмент
# 29  2024                                          Экономика
# 30  2024               Информатика и вычислительная техника
# 31  2024                                         Психология
# 32  2024                                    Здравоохранение
# 33  2024                                         Психология
# 34  2024                                Физическая культура
# 35  2024               Информатика и вычислительная техника
# 36  2024  Психолого-педагогическое и специальное (дефект...
# 37  2024                         Педагогическое образование
# 38  2024                    Лингвистика и иностранные языки
# 39  2024                      Приборостроение и оптотехника
# 40  2024                                      Строительство
# 41  2024                                             Дизайн
# 42  2024                        Информационная безопасность
# 43  2024                                         Менеджмент
# 44  2024                   Архитектура и градостроительство
# 45  2024               Информатика и вычислительная техника
# 46  2024                                          Экономика
# 47  2024                   Технологии легкой промышленности
# 48  2024         Государственное и муниципальное управление
# 49  2024                    Лингвистика и иностранные языки
#
#                                            university  avg_ege_paid  \
# 0                    Адыгейский гос. ун-т., г. Майкоп          58.6
# 1                    Адыгейский гос. ун-т., г. Майкоп          55.7
# 2                    Адыгейский гос. ун-т., г. Майкоп          52.0
# 3                    Адыгейский гос. ун-т., г. Майкоп          57.2
# 14                  -2.3             92                 100.1            NaN
# 15                   4.8             13                 100.1            NaN
# 16                   NaN              7                 100.1            NaN
# 17                  -6.5             38                 100.1            NaN
# 18                  -6.5             97                 134.5            NaN
# 19                 -14.2             14                 100.1            NaN
# 20                   NaN             11                 100.1            NaN
# 21                  -3.4             16                 210.0            NaN
# 22                  -5.5             10                 210.0            NaN
# 23                   NaN              2                 210.0            NaN
# 24                 -10.8              7                 210.0            NaN
# 25                  -6.8             32                 230.0            NaN
# 26                  -4.2             15                 210.0            NaN
# 27                  -3.7             24                 120.0            NaN
# 28                  -0.8             24                 120.0            NaN
# 29                  11.0              3                 120.0            NaN
# 30                   NaN              9                 126.0            NaN
# 31                  -0.3             11                 120.0            NaN
# 32                  -0.1            182                 196.4           67.1
# 33                  -4.5             27                 133.3           71.2
# 34                   NaN              3                 160.6           68.0
# 35                   NaN              2                 132.1           56.3
# 36                  -0.9              8                 115.6           62.8
# 37                   0.2             88                 115.6           61.9
# 38                  -3.1             10                 124.6           80.5
# 39                   NaN              2                 140.0           62.6
# 40                   NaN              3                 140.0           61.6
# 41                  10.1             13                 230.0           90.7
# 42                 -10.8             11                 135.0           70.1
# 43                  -5.0             12                 140.0           56.0
# 44                   7.1             10                 140.0           73.9
# 45                  -4.8             43                 135.0           72.5
# 46                  -2.7             26                 140.0            NaN
# 47                   NaN              3                 140.0           72.0
# 48                  -2.4              6                 140.0            NaN
# 49                   1.3             22                 118.6           83.2
#
#     enrolled_budget ege_excludes_individual  ...  inflation_rate_percent  \
# 0               0.0                      Да  ...                     7.4
# 1              10.0                      Да  ...                     7.4
# 2              12.0                      Да  ...                     7.4
# 3              22.0                      Да  ...                     7.4
# 4              50.0                      Да  ...                     7.4
# 5               0.0                      Да  ...                     7.4
# 6              29.0                      Да  ...                     7.4
# 7             146.0                      Да  ...                     7.4
# 8              25.0                      Да  ...                     7.4
# 9              69.0                     Нет  ...                     7.4
# 10              0.0                      Да  ...                     7.4
# 11              0.0                      Да  ...                     7.4
# 12              0.0                      Да  ...                     7.4
# 13              0.0                      Да  ...                     7.4
# 14              0.0                      Да  ...                     7.4
# 15              0.0                      Да  ...                     7.4
# 16              0.0                      Да  ...                     7.4
# 17              0.0                      Да  ...                     7.4
# 18              0.0                      Да  ...                     7.4
# 19              0.0                      Да  ...                     7.4
# 20              0.0                      Да  ...                     7.4
# 21              0.0                      Да  ...                     7.4
# 22              0.0                      Да  ...                     7.4
# 23              0.0                      Да  ...                     7.4
# 24              0.0                      Да  ...                     7.4
# 25              0.0                      Да  ...                     7.4
# 26              0.0                      Да  ...                     7.4
# 27              0.0                      Да  ...                     7.4
# 28              0.0                      Да  ...                     7.4
# 29              0.0                      Да  ...                     7.4
# 30              0.0                      Да  ...                     7.4
# 31              0.0                      Да  ...                     7.4
# 32            720.0                      Да  ...                     7.4
# 33             15.0                      Да  ...                     7.4
# 34             19.0                      Да  ...                     7.4
# 45      19.2            75.0                         8.5      251.3     100.6
# 46      19.2            75.0                         8.5      251.3     100.6
# 47      19.2            75.0                         8.5      251.3     100.6
# 48      19.2            75.0                         8.5      251.3     100.6
# 49      19.2            75.0                         8.5      251.3     100.6
#
#     base_inflation_percent  gdp_deflator  population_million  \
# 0                     7.15         129.4               146.2
# 1                     7.15         129.4               146.2
# 2                     7.15         129.4               146.2
# 3                     7.15         129.4               146.2
# 4                     7.15         129.4               146.2
# 5                     7.15         129.4               146.2
# 6                     7.15         129.4               146.2
# 7                     7.15         129.4               146.2
# 8                     7.15         129.4               146.2
# 9                     7.15         129.4               146.2
# 10                    7.15         129.4               146.2
# 11                    7.15         129.4               146.2
# 12                    7.15         129.4               146.2
# 13                    7.15         129.4               146.2
# 14                    7.15         129.4               146.2
# 15                    7.15         129.4               146.2
# 16                    7.15         129.4               146.2
# 17                    7.15         129.4               146.2
# 18                    7.15         129.4               146.2
# 19                    7.15         129.4               146.2
# 20                    7.15         129.4               146.2
# 21                    7.15         129.4               146.2
# 22                    7.15         129.4               146.2
# 23                    7.15         129.4               146.2
# 24                    7.15         129.4               146.2
# 25                    7.15         129.4               146.2
# 26                    7.15         129.4               146.2
# 27                    7.15         129.4               146.2
# 28                    7.15         129.4               146.2
# 29                    7.15         129.4               146.2
# 30                    7.15         129.4               146.2
# 31                    7.15         129.4               146.2
# 32                    7.15         129.4               146.2
# 33                    7.15         129.4               146.2
# 34                    7.15         129.4               146.2
# 35                    7.15         129.4               146.2
# 36                    7.15         129.4               146.2
# 37                    7.15         129.4               146.2
# 38                    7.15         129.4               146.2
# 39                    7.15         129.4               146.2
# 40                    7.15         129.4               146.2
# 41                    7.15         129.4               146.2
# 42                    7.15         129.4               146.2
# 43                    7.15         129.4               146.2
# 44                    7.15         129.4               146.2
# 45                    7.15         129.4               146.2
# 46                    7.15         129.4               146.2
# 47                    7.15         129.4               146.2
# 48                    7.15         129.4               146.2
# 49                    7.15         129.4               146.2
#
#     unemployment_rate_percent
# 0                         2.9
# 1                         2.9
# 2                         2.9
# 3                         2.9
# 4                         2.9
# 5                         2.9
# 6                         2.9
# 7                         2.9
# 8                         2.9
# 9                         2.9
# 10                        2.9
# 11                        2.9
# 12                        2.9
# 13                        2.9
# 14                        2.9
# 15                        2.9
# 16                        2.9
# 17                        2.9
# 18                        2.9
# 19                        2.9
# 20                        2.9
# 21                        2.9
# 22                        2.9
# 23                        2.9
# 24                        2.9
# 25                        2.9
# 26                        2.9
# 27                        2.9
# 28                        2.9
# 29                        2.9
# 30                        2.9
# 31                        2.9
# 32                        2.9
# 33                        2.9
# 34                        2.9
# 35                        2.9
# 36                        2.9
# 37                        2.9
# 38                        2.9
# 39                        2.9
# 40                        2.9
# 41                        2.9
# 42                        2.9
# 43                        2.9
# 44                        2.9
# 45                        2.9
# 46                        2.9
# 47                        2.9
# 48                        2.9
# 49                        2.9
#
# [50 rows x 23 columns]
